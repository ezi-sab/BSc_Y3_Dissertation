# %% [markdown]
# # Rules from Serotypes
# The rules between serotypes.
#
# Assume. Genes under the bonds are related to "next sugar".

# %%
rules = dict()

# %%
#Serotype 6
rules ['wchA'] = glucose
rules ['wciN'] = galactose
rules ['wciO'] = ribitol
rules ['wciP'] = rhamnose

#Serotype 7
rules ['wchA'] = glucose
rules ['wchF'] = rhamnose
rules ['wcwA'] = galactose
rules ['wcwC'] = N-acetylgalactosamine
#from 7B
rules ['wcwI'] = rhamnose
rules ['wcwL'] = N-acetylglucosamine
rules ['wcwK'] = glucose
rules ['wcxU'] = rhamnose
rules ['rsbF'] = ribose-f 
#from 7F
rules ['wcwD'] = side_P-galactose

#Serotype 9
rules ['wchA'] = glucose
rules ['wchO'] = N-acetylmannosamine
#rules ['wcjA'] = galactose #-> glucose in 9N
rules ['wcjB'] = glucuronic acid
#rules ['wcjC'] = glucose #-> N-acetylglucosamine in 9L & 9N 
#from 9V
#rules ['wcjE'] = Modification

#Serotype 10
rules ['wcjG'] = galactose
rules ['wciB'] = galactose
rules ['wcrB'] = ribitol
rules ['wcrC'] = galactose
rules ['wciF'] = N-acetylgalactosamine

#Serotype 11
rules ['wchA'] = glucose
rules ['gct'] = glycerol 
#from 11F
rules ['wcwC'] = ribitol
#from 11C
rules ['wcwR'] = N-acetylglucosamine

#Serotype 12
rules ['wciI'] = N-acetylgalactosamine
rules ['wciJ'] = N-acetylfucosamine
rules ['wcxD'] = N-acetylmannosaminuronic acid
rules ['wcxE'] = glucose
rules ['wcxF'] = glucose

#Serotype 15
rules ['wchA'] = glucose
rules ['wchK'] = galactose
rules ['wchL'] = N-acetylglucosamine
rules ['wchM'] = galactose
rules ['wchN'] = galactose
#from 15F
rules ['wciZ'] = choline0.2 

#Serotype 17
rules ['wchA'] = glucose
#rules ['wcrT', 'wcrU', 'wcrV', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] -> rhamnose / rhamnose / galactose / side_P-galactose

#Serotype 18
rules ['wchA'] = glucose
rules ['wchF'] = rhamnose
#from 18F&18C
rules ['wciX'] = side_glycerol   
#rules ['wciU', 'wciV', 'wciW', 'wciX', 'wciY', 'gct', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] ->  glucose / galactose / glucose / side_glycerol
#rules ['wciU', 'wciV', 'wciW', 'wciY', 'gct', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] -> glucose / galactose / glucose
#rules ['wciU', 'wciV', 'wciW', 'wciY', 'gct', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] -> galactose / glucose / side_D-glycerol
#rules ['wciU', 'wciV', 'wciW', 'wciY', 'gct', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] -> glucose / galactose / glucose

#Serotype 19
rules ['wchA'] = glucose
#from 19C
rules ['wchU'] = side_P-glucose
#rules ['wchO', 'wchP', 'wchQ', 'mnaA', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] -> N-acetylmannosamine / rhamnose
#rules ['wchO', 'wchP', 'wchQ', 'wchR', 'wchS', 'rbsF', 'mnaA', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] -> N-acetylmannosamine / rhamnose / N-acetylmannosamine / rhamnose / D-Ribf

#Serotype 32
rules ['wchA'] = glucose
rules ['wchF'] = rhamnose
#rules ['wcyH', 'wcyI', 'wchQ', 'wcyS', 'wcrN', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] -> glucose / rhamnose / side_choline

#Serotype 33
rules ['wchA'] = glucose
rules ['wciD'] = galactose
rules ['wciE'] = galactose
rules ['wciF'] = side_P-galactose

#Serotype 35
rules ['wchA'] = glucose
#rules ['wciB', 'wcrJ', 'wcrH', 'wciG', 'glf'] -> galactose / galactose

# %%
# #Predict
# #from 7A
# rules ['wcwA', 'wcwC', 'wcwF', 'wcwG', 'wcwH'] -> galactose / N-acetylgalactosamine / rhamnose / N-acetylglucosamine #Not correspond
# #from 7A & 7F
# rules ['wcwF', 'wcwG', 'wcwG'] -> rhamnose / N-acetylglucosamine #Not correspond
# #from 10F
# rules ['wciG'] or gene ['wcrH'] -> side_F-galactose(4th)
# #from 10A
# rules ['wcrD'] or gene ['wcrG'] -> galactose(6th sugar) / side_P-galactose(5th) #Not correspond
# #from 11C
# rules ['wcwR'] or gene ['gct'] -> glycerol
# #from 11A
# rules ['wcwC'] or gene ['wcjE'] -> glucose
# #from 12F and 12A _ Same gene -> Different sugars
# rules ['wcxB'] -> side_P-galactose
# rules ['wcxB'] -> side_P-N-acetylgalactosamine
# #from 15F and 15A _ Same gene -> Different sugars
# rules ['wchX'] -> choline0.2
# rules ['wchX'] -> glycerol0.7
# #from 17F
# rules ['wchF', 'wcxG', 'abp1', 'abp2', 'wciP'] -> rhamnose / arabinitol #Not correspond
# #from 17A
# rules ['wciB', 'wcrP', 'wcrQ', 'wcrR', 'ugd', 'glf'] -> galactose / glucuronic acid / side_P-glucose #Not correspond
# #from 18F
# rules ['wcxM'] -> ?
# #from 33F
# rules ['wciB', 'wciC', 'wciG*'] -> galactose(2nd) / galactose(4th) #Not correspond
# #from 33B
# rules ['wciN', 'wciO', 'wcrC', 'wciE'] -> ribitol / N-acetylgalactosamine #Not correspond
# #from 35A
# rules ['wcrI', 'mnp1', 'mnp2', 'wcjE'] -> galactose / mannitol #Not correspond
# #from 35B
# rules ['wcrM'] -> N-acetylgalactosamine / ribitol #Not correspond
