# %% [markdown]
# # Rules from Serotypes
# The rules between serotypes.
#
# Assume. Genes under the bonds are related to "bond type".

# %%
rules = dict()

# %%
#Rules of bonds

#Serotype 6
# rules ['wciN'] = a1-3
# rules ['wciO'] = 5-P-2
# rules ['wciP'] = a1-3 or a1-4

#Serotype 9
# rules ['wchO'] = b1-4
# rules ['wcjA'] = a1-3
# rules ['wcjB'] = a1-3
# rules ['wcjC'] = a1-4

# %%
#Rules of sugars

#Serotype 6
rules ['wchA'] = glucose
rules ['rmlA', 'rmlC', 'rmlB', 'rmlD'] = rhamnose

#Serotype 7
rules ['wchA'] = glucose
rules ['wchF'] = rhamnose
rules ['rmlA', 'rmlC', 'rmlB', 'rmlD'] = rhamnose 
#from 7B
rules ['wcwI'] = rhamnose
rules ['wcwL'] = N-acetylglucosamine
rules ['wcwK'] = glucose
rules ['wcxU'] = rhamnose #Q.If so, how to explain gene ['rmlA', 'rmlC', 'rmlB', 'rmlD'] -> rhamnose?
rules ['rsbF'] = ribose-f
#from 7F
rules ['wcwD'] = side_P-galactose

#Serotype 9
rules ['wchA'] = glucose
rules ['mnaA'] = N-acetylmannosamine
rules ['wcjD'] = galactose
rules ['ugd'] = glucuronic acid
#from 9V
#rules ['wcjE'] -> Modification
#from 9A
rules ['wcjD'] = glucose

#Serotype 10
rules ['wcjG'] = galactose
rules ['wciB'] = galactose
rules ['wcrB'] = ribitol
rules ['wcrC'] = galactose
rules ['wciF'] = N-acetylgalactosamine
#from 10A
rules ['wcrD'] = galactose
rules ['wcrG'] = side_P-galactose

#Serotype 11
rules ['wchA'] = glucose
#from 11F
rules ['wcwC'] = ribitol
#from 11C
rules['gct'] = glycerol 
rules ['wcwR'] = N-acetylglucosamine
#rules ['wchJ', 'wchK', 'wcyK', 'wcrL', 'wcwT', 'wcwU'] -> galactose / galactose / N-acetylglucosamine / ribitol #Not correspond
#rules ['wchJ', 'wchK', 'wcyK', 'wcrL', 'wcwT', 'wcwU'] -> galactose / galactose / N-acetylglucosamine #Not correspond
#rules ['wchJ', 'wchK', 'wcyK', 'wcrL', 'wcwT', 'wcwU'] -> galactose / galactose #Not correspond

#Serotype 12
rules ['wciI'] = N-acetylgalactosamine
rules ['fnlA', 'fnlB', 'fnlC'] = N-acetylfucosamine
rules ['mnaB', 'mnaA'] = N-acetylmannosaminuronic acid
#gene ['wciJ', 'wcxB', 'wcxD', 'wcxE', 'wcxF'] -> glucose / glucose #Not correspond

#Serotype 15
rules ['wchA'] = glucose
#from 15F
rules ['wciZ'] = side_choline0.2
#gene ['wchJ', 'wchK', 'wchL', 'wchM', 'wchN', 'wchX', 'gtp1', 'gtp2', 'gtp3'] -> galactose / N-acetylglucosamine / galactose / galactose #Not correspond

#Serotype 17
rules ['wchA'] = glucose
#from 17F
rules ['wchF'] = rhamnose
#from 17A
rules ['ugd'] = glucuronic acid
#rules ['wcrT', 'wcrU', 'wcrV', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] -> rhamnose / rhamnose / galactose #Not correspond

#Serotype 18
rules ['wchA'] = glucose
rules ['wchF'] = rhamnose
#from 18F
#rules ['wcxM'] -> Modification
rules ['wciX'] = side_glycerol #Also from 18C
#rules ['wciU', 'wciV', 'wciW', 'wciX', 'wciY', 'gct', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] -> glucose / galactose / glucose / side_glycerol
#rules ['wciU', 'wciV', 'wciW', 'wciY', 'gct', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] -> glucose / galactose / glucose
#rules ['wciU', 'wciV', 'wciW', 'wciY', 'gct', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] -> galactose / glucose / side_D-glycerol

#Serotype 19
rules ['wchA'] = glucose
#from 19C
rules ['wchU'] = side_P-glucose
#rules ['wchO', 'wchP', 'wchQ', 'mnaA', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] -> N-acetylmannosamine / rhamnose #Not correspond
#rules ['wchO', 'wchP', 'wchQ', 'wchR', 'wchS', 'rbsF', 'mnaA', 'rmlA', 'rmlC', 'rmlB', 'rmlD'] ->  N-acetylmannosamine / rhamnose / N-acetylmannosamine / rhamnose / D-Ribf #Not correspond

#Serotype 32
rules ['wchA'] = glucose
rules ['wchF'] = rhamnose
rules ['rmlA', 'rmlC', 'rmlB', 'rmlD'] = rhamnose
#rules ['wcyH', 'wcyI', 'wchQ', 'wcyS', 'wcrN'] -> glucose

#Serotype 33
rules ['wchA'] = glucose
rules ['wciD'] = galactose
rules ['wciF'] = galactose
rules ['wciE'] = side_P-galactose


#Serotype 35
rules ['wchA'] = glucose
#rules ['wciB', 'wcrJ', 'wcrH', 'wciG'] -> galactose / galactose

# %%
# # Predict
# #from 7A
# rules ['wcwA', 'wcwC', 'wcwF', 'wcwG', 'wcwH'] -> galactose / N-acetylgalactosamine / rhamnose / N-acetylglucosamine #Not correspond
# #from 10F
# rules ['wciG'] or gene['wcrH'] -> side_F-galactose
# #from 11A
# rules ['wcwC'] or gene ['wcjE'] -> glucose
# #from 17F
# rules ['wcxG', 'abp1', 'abp2', 'wciP'] -> arabinitol
# #from 17A
# rules ['wciB', 'wcrP', 'wcrQ', 'wcrR'] -> galactose / side_P-glucos
# #from 33F
# rules ['wciB', 'wciC', 'wciG*'] -> galactose / galactose
# #from 33B
# rules ['wciN', 'wciO', 'wcrC', 'wciG'] -> ribitol / N-acetylgalactosamine
# #from 35A
# rules ['wcrI', 'wcrK', 'mnp1', 'mnp2', 'wcjE'] -> galactose / mannitol
# #from 35B
# rules ['wcrM'] -> N-acetylgalactosamine or ribitol

# %%
rules
# Out:
# {'wchA': 'glucose',
#  'wchF': 'rhamnose',
#  ('rmlA', 'rmlC', 'rmlB', 'rmlD'): 'rhamnose',
#  'wcwD': 'side_P-galactose',
#  'mnaA': 'N-acetylmannosamine',
#  'ugd': 'glucuronic acid',
#  'wcjG': 'galactose',
#  'wciB': 'galactose',
#  'wcrB': 'ribitol',
#  'wcrC': 'galactose',
#  'wciF': 'N-acetylgalactosamine',
#  'gct': 'glucose',
#  'wciI': 'N-acetylmannosamine',
#  ('fnlA', 'fnlB', 'fnlC'): 'N-acetylgalactosamine',
#  ('mnaB', 'mnaA'): 'N-acetylmannosaminuronic acid',
#  'wciG': 'N-acetylgalactosamine'}
