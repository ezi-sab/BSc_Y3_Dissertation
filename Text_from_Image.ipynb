# %%
from Serotype_Data import *

from Bio.Seq import Seq
from Bio.pairwise2 import format_alignment
from Bio import pairwise2

import cv2
import pytesseract
from PIL import Image, ImageOps

import numpy as np

# %%
img = Image.open('17.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=924x156 at 0x7F997E8C8160>

# %%
text = pytesseract.image_to_string(img)
text
# Out:
# ' \n\n(a1-6) A S - A\n& (1-2) {FI (a1-3) {P| (a1-3) {P| (B1-4) wchA ,\n. v v\n\nwzy25 (B1-3)\n\x0c'
